# %% [markdown]
# # Basic Usage Tutorial for SPIDER
#
# This is a minimum working example to show how to use SPIDER. Please make sure you have Nvidia GPU and CUDA installed. Create environment with `uv sync`.

# %%
from spider.config import Config, process_config

# %%
config = Config(
    robot_type="xhand",
    embodiment_type="bimanual",
    task="p36-tea", 
    data_id=10, 
)
process_config(config)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 7
#       1 config = Config(
#       2     robot_type="xhand",
#       3     embodiment_type="bimanual",
#       4     task="p36-tea",
#       5     data_id=10,
#       6 )
# ----> 7 process_config(config)
#
# File ~/Research/code/spider/spider/config.py:245, in process_config(config)
#     242     config.npair = model.npair
#     244 # get noise scale
# --> 245 config = compute_noise_schedule(config)
#     247 # output dir: write artifacts alongside the trial
#     248 config.output_dir = processed_dir_robot
#
# File ~/Research/code/spider/spider/config.py:197, in compute_noise_schedule(config)
#     196 def compute_noise_schedule(config: Config) -> Config:
# --> 197     config.noise_scale = get_noise_scale(config)
#     198     if config.max_num_iterations > 0:
# ...

# %% [markdown]
# ## Process Dataset
#
# Here we use Gigahands as example. More dataset processing pipeline can be found in `spider/processed_datasets`. Dataset instruction can be found [here](https://facebookresearch.github.io/spider/development/add-dataset.html).

# %%
from spider.process_datasets.gigahand import main as process_gigahands
